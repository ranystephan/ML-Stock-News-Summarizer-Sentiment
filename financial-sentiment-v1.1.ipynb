# %%
# NLP package used to aid in text manipulation
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
# Machine Learning modules used to prepare and measure text
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import BertTokenizer, BertForSequenceClassification, pipeline
import torch
# HTML text processing
from bs4 import BeautifulSoup
# Helper modules
import matplotlib.pyplot as plt
from tqdm.notebook import trange # Progress bar
# Refinitiv packages to extract filings data and retrieve price data
import refinitiv.data as rd
from refinitiv.data.content import filings
# Convenient modules to simplify API access to Filings
# %run ./FilingsQuery.ipynb
# %run ./SymbolLookup.ipynb
pd.set_option('display.max_colwidth', 60)
# Out:
# /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages/scipy/__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File ~/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages/IPython/utils/path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'./FilingsQuery.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 17
#      15 from refinitiv.data.content import filings
#      16 # Convenient modules to simplify API access to Filings
# ---> 17 get_ipython().run_line_magic('run', './FilingsQuery.ipynb')
#      18 get_ipython().run_line_magic('run', './SymbolLookup.ipynb')
#      19 pd.set_option('display.max_colwidth', 60)
#
# File ~/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2432, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2430     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2431 with self.builtin_trap:
# -> 2432     result = fn(*args, **kwargs)
#    2434 # The code below prevents the output from being displayed
#    2435 # when using magics with decorator @output_can_be_silenced
#    2436 # when the last Python token in the expression is a ';'.
#    2437 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages/IPython/core/magics/execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     725     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     726         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 727     raise Exception(msg) from e
#     728 except TypeError:
#     729     if fpath in sys.meta_path:
#
# Exception: File `'./FilingsQuery.ipynb'` not found.

# %%
pip install refinitiv.data
# Out:
# Collecting refinitiv.data
#   Using cached refinitiv_data-1.4.0-py3-none-any.whl (878 kB)
# Collecting pyhumps<=3.8.0,~=3.0.2
#   Downloading pyhumps-3.0.2-py3-none-any.whl (5.1 kB)
# Collecting tenacity<8.1.0,>=8.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: python-dateutil<=2.8.2 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from refinitiv.data) (2.8.2)
# Collecting watchdog<=2.1.9,>=0.10.2
#   Downloading watchdog-2.1.9-py3-none-manylinux2014_x86_64.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 KB 617.3 kB/s eta 0:00:00a 0:00:01
# Collecting httpx<=0.24.1,>=0.18
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 KB 682.2 kB/s eta 0:00:00a 0:00:01
# Collecting numpy<=1.23.4,>=1.11.0
#   Downloading numpy-1.23.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 215.0 kB/s eta 0:00:0000:0100:03
# Collecting pandas<=2.0.2,>=1.3.5
#   Downloading pandas-2.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 312.3 kB/s eta 0:00:0000:0100:02
# Collecting appdirs<=1.4.4,>=1.4.3
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting websocket-client!=1.2.2,<=1.5.1,>=0.58.0
#   Downloading websocket_client-1.5.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 KB 621.1 kB/s eta 0:00:00a 0:00:01
# Collecting scipy<=1.9.3
#   Downloading scipy-1.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 403.3 kB/s eta 0:00:0000:0100:03
# Requirement already satisfied: jinja2<4.0.0,>=3.0.3 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from refinitiv.data) (3.1.2)
# Collecting requests<=2.28.1
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 661.6 kB/s eta 0:00:00a 0:00:01
# Collecting httpcore<=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 KB 653.8 kB/s eta 0:00:00a 0:00:01
# Collecting simplejson~=3.15
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 KB 954.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six<=1.16.0 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from refinitiv.data) (1.16.0)
# Collecting pyee<=9.0.4
#   Downloading pyee-9.0.4-py2.py3-none-any.whl (14 kB)
# Collecting PyMySQL>=1.0.2
#   Downloading PyMySQL-1.1.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 KB 611.2 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: certifi in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from httpcore<=0.15.0->refinitiv.data) (2023.7.22)
# Requirement already satisfied: sniffio==1.* in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from httpcore<=0.15.0->refinitiv.data) (1.3.0)
# Collecting anyio==3.*
#   Downloading anyio-3.7.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 655.8 kB/s eta 0:00:00a 0:00:01
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 706.3 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: idna>=2.8 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from anyio==3.*->httpcore<=0.15.0->refinitiv.data) (3.4)
# Requirement already satisfied: exceptiongroup in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from anyio==3.*->httpcore<=0.15.0->refinitiv.data) (1.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from jinja2<4.0.0,>=3.0.3->refinitiv.data) (2.1.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from pandas<=2.0.2,>=1.3.5->refinitiv.data) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from pandas<=2.0.2,>=1.3.5->refinitiv.data) (2023.3)
# Requirement already satisfied: typing-extensions in /home/ranystephan/Projects/Research Paper/NeuralFin-GPT/NeuralFin-GPT-Lab/cuda/lib/python3.10/site-packages (from pyee<=9.0.4->refinitiv.data) (4.8.0)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 KB 567.2 kB/s eta 0:00:00a 0:00:01
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Installing collected packages: pyhumps, appdirs, websocket-client, watchdog, urllib3, tenacity, simplejson, PyMySQL, pyee, numpy, h11, charset-normalizer, anyio, scipy, requests, pandas, httpcore, httpx, refinitiv.data
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.1
#     Uninstalling numpy-1.26.1:
#       Successfully uninstalled numpy-1.26.1
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 3.3.0
#     Uninstalling charset-normalizer-3.3.0:
#       Successfully uninstalled charset-normalizer-3.3.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.0.0
#     Uninstalling anyio-4.0.0:
#       Successfully uninstalled anyio-4.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.2
#     Uninstalling pandas-2.1.2:
#       Successfully uninstalled pandas-2.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyterlab-server 2.25.0 requires requests>=2.31, but you have requests 2.28.1 which is incompatible.
# Successfully installed PyMySQL-1.1.0 anyio-3.7.1 appdirs-1.4.4 charset-normalizer-2.1.1 h11-0.12.0 httpcore-0.15.0 httpx-0.24.1 numpy-1.23.4 pandas-2.0.2 pyee-9.0.4 pyhumps-3.0.2 refinitiv.data-1.4.0 requests-2.28.1 scipy-1.9.3 simplejson-3.19.2 tenacity-8.0.1 urllib3-1.26.18 watchdog-2.1.9 websocket-client-1.5.1
# Note: you may need to restart the kernel to use updated packages.
